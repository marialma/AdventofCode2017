# %%
aoc = list("...")
aocsum = []
for index,n in enumerate(aoc):
    if index == 0:
        prevnum = int(n)
        startnum = int(n)
    else:
        if int(n) != int(prevnum):
            prevnum = int(n)
        else:
            aocsum.append(int(n))
            prevnum =  int(n)
        if index == (len(aoc)-1):
            print(len(aoc))
            if int(n) == int(startnum):
                aocsum.append(int(n))
            else: 
                pass
        else: 
            pass
                
print(aocsum)
sum(aocsum)
# Out:
# 2014
# [9, 9, 6, 8, 8, 8, 8, 6, 8, 2, 9, 5, 5, 9, 6, 9, 4, 5, 9, 5, 2, 6, 6, 4, 1, 1, 6, 3, 2, 3, 1, 1, 8, 3, 2, 2, 7, 7, 7, 8, 6, 1, 3, 8, 2, 2, 2, 9, 1, 6, 3, 5, 3, 1, 6, 9, 7, 2, 2, 6, 5, 3, 1, 1, 1, 3, 1, 1, 8, 3, 9, 3, 4, 5, 4, 8, 8, 6, 7, 7, 5, 5, 9, 6, 6, 6, 3, 4, 1, 5, 4, 4, 6, 6, 4, 9, 1, 5, 6, 3, 5, 2, 9, 3, 2, 8, 6, 1, 1, 6, 3, 7, 4, 1, 8, 9, 8, 6, 8, 5, 9, 9, 2, 7, 9, 6, 8, 7, 4, 4, 9, 4, 2, 6, 1, 2, 2, 3, 8, 4, 7, 1, 1, 9, 9, 7, 7, 7, 9, 4, 5, 8, 3, 1, 7, 5, 6, 7, 7, 5, 5, 2, 5, 9, 3, 5, 1, 9, 9, 4, 9, 6, 1, 9, 6, 6, 1, 1, 5, 3, 5, 5, 5, 8, 8, 8, 1, 4, 6, 8, 2, 4, 2, 1, 2, 3, 2, 1, 9, 2, 9, 4, 4, 7, 9, 2, 2, 4, 4, 2, 8, 8, 4, 1, 5, 3, 8, 7, 4, 1, 1, 7, 9, 9, 9, 9, 1, 4, 3, 4, 6, 1, 3]
# 1158

# %%
asdf = [(i,j) for i,j in enumerate(aoc)]
print(asdf)
